# %%
import matplotlib.pyplot as plt
from data_loader import load_train_data

# %%
train_path = 'flat_mnist_train_aug_28x28_30000.gz'
test_path = 'flat_mnist_test_aug_28x28.gz'

train_data = load_train_data(train_path)
test_data = load_train_data(test_path)

# %%
for i in range(10):
    print(train_data[i][1])
    plt.imshow(train_data[i][0][0], cmap='gray')
    plt.show()
# Out:
# tensor(0)
# tensor(4)
# tensor(0)
# tensor(7)
# tensor(4)
# tensor(6)
# tensor(7)
# tensor(0)
# tensor(8)
# tensor(1)

# %%
for i in range(10):
    print(test_data[i][1])
    plt.imshow(test_data[i][0][0], cmap='gray')
    plt.show()
# Out:
# tensor(7)
# tensor(2)
# tensor(1)
# tensor(0)
# tensor(4)
# tensor(1)
# tensor(4)
# tensor(9)
# tensor(5)
# tensor(9)

# %%
print(len(train_data))
# Out:
# 30000
